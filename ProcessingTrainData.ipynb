# %% [markdown]
# # Import & examine data

# %%
import pandas as pd
import os
from pathlib import Path

cwd = Path(os.getcwd())
cmts_csv = cwd / 'Data' / 'Comments_20210319_005325.csv'
posts_csv = cwd / 'Data' / 'Posts_20210319_005325.csv'

cmts_df = pd.read_csv(cmts_csv,sep=',',index_col=0)
cmts_df.head(15)
# Out:
#    comment_id post_id                                               body  \
# 0     grfoljw  m86g8n  Here's the first in a project I've been workin...
# 1     grf99dk  m7y9rp  This subclass has features requiring the *Psyc...
# 2     grd344y  m7s097  Hello, everyone!  Hoping to get some serious c...
# 3     gr9amwd  m75i2f  When I say partly inspired by Hollow Knight, I...
# 4     gr99ryw  m75bsj  Note: The class currently just uses the Warloc...
# 5     gr8y8lg  m73c7l  Hi everyone! This a subclass that I've been th...
# 6     gr67wsv  m6kq63  Survey [here](https://docs.google.com/forms/d/...
# 7     gr577dw  m68lk9  [https://homebrewery.naturalcrit.com/share/5L4...
# 8     gr2twa9  m5y7f2  [Link to my Homebrewer Version](https://homebr...
# 9     gqyg3ll  m56sxy  I think most people here know by now that WOTC...
# 10    gr1fhsw  m55qyx  This is a cool concept, I have a draft I'm wor...
# 11    gqvj5b1  m4pee6  Hey everyone! Barbarian isn't a class I know p...
# 12    gqtr7oo  m4d83w  First I would like to say this is my second tr...
# 13    gqrza8e  m3unc3  Here are some supportive blood curses from u/r...
# 14    gqp9dpa  m3kg2v  Hi everyone! I'm back today with another homeb...
#
#                 sub                                         post_title  \
# 0   UnearthedArcana          Variant Hobgoblin - Emporium of the Races
# 1   UnearthedArcana  Bard - College of Forgotten Echoes; a spiritua...
# 2   UnearthedArcana  Fortune Domain - 5e Cleric Subclass (CONSTRUCT...
# 3   UnearthedArcana  Bugfolk, a Race of Creepy-Crawlies Partly Insp...
# 4   UnearthedArcana  The Eldritch Brawler | Class with a unique, fa...
# 5   UnearthedArcana  Oath of Self - A Paladin subclass for those wh...
# 6   UnearthedArcana                       Ranger - Crystalline Trapper
# 7   UnearthedArcana        Greywatcher: An Advanced Demon Hunter Class
# 8   UnearthedArcana  Gourd of the Dragon Lords - a "Journey to the ...
# 9   UnearthedArcana                            Fairy Race Remixed (5e)
# 10  UnearthedArcana  Hunger based warlock subclass Pact of the Wendigo
# 11  UnearthedArcana  Barbarian: Path of the Iron Fist - Strong arm ...
# 12  UnearthedArcana  The Merchant a fake god on a material plane an...
# 13  UnearthedArcana                       Support Focused Blood Curses
# 14  UnearthedArcana  Your Bard can walk the dog and rock the baby w...
#
#     post_flair
# 0         Race
# 1     Subclass
# 2     Subclass
# 3         Race
# 4        Class
# 5     Subclass
# 6     Subclass
# 7        Class
# 8         Item
# 9         Race
# 10    Subclass
# 11    Subclass
# 12  Compendium
# 13     Feature
# 14    Subclass

# %% [markdown]
# ### Exploring comments...
# Let's print the first 10 comments in full to see how it looks

# %%
for i in cmts_df['body'][0:9]:
    print(i+"\n")
# Out:
# Here's the first in a project I've been working on for a while: Emporium of the Races! Essentially, I aim to upgrade and add new options for every race in 5e, as well as introduce new Versatile Subraces inspired by Pathfinder 2e's versatile heritages. I will post updates to this project every week. If you have any suggestions, comments, or requests feel free to share.
#
# For this first entry, I've decided to do my favorite race: Hobgoblins.   The Strongblade Hobgoblin is essentially the original race, the Forge Hobgoblin makes a great artificer, The aquatic Koalinth is an old d&d monster that I'm surprised hasn't been made playable yet, and the Drakogoblin is an original subrace based on Hobgoblins apparent penchant for drakes. Tell me what you would like me to cover next!
#
# Gmbinder Link: https://www.gmbinder.com/share/-MW5xKc1QPj4TXEgBzQm
#
# Google Drive Link: https://drive.google.com/file/d/1fxn2YHNDnM2W8KJPV_17tpmpyFxqeWJS/view?usp=sharing
#
# This subclass has features requiring the *Psychic and Spiritual Handbook* by Therin Creative.
#
# You can get it at [GM Binder](https://www.gmbinder.com/share/-MVeY68xfxI2MrESmAq0) and [Therin Creative](https://therincreative.com/bard-college-of-forgotten-echoes/).
#
# This is the first new content supplementing the *Psychic and Spiritual Handbook* (PSHB). More will follow throughout 2021. The PSHB is a resource with a number of new rules, many of which are standalone.
#
# You can get the PSHB at [GM Binder](https://www.gmbinder.com/share/-M90l_C5MPCYvWvO1mpD) for book quality or [Therin Creative](https://therincreative.com/5epsi/) for web version.
#
# If  you like the flavor but don't want to use the PSHB for whatever reason,  you are free to convert it for your own use. The Lay to Rest and  Haunting Echoes features draw from the PSHB (Spiritfonts and the  Unsettled Condition).
#
# Hello, everyone!  Hoping to get some serious constructive feedback on this cleric subclass that I've made. Just a little background - I'm planning a campaign that takes place in the Lendore Isles, and there is a church introduced in the Secret of Bone Hill called the "Church of the Big Gamble."  I would like to offer my players the chance to become a member of their faith, and 5e lacks a cleric domain that fits this church.
#
# The Fortune Domain is not about making money, but about good and bad luck.  Clerics manipulate chance for good (fortune) or bad (misfortune), and this subclass plays a support role.  I haven't made too many subclasses for 5e, so I'm looking for some feedback and critiques of this subclass, as well as suggestions for how it might best fit the theme of a cleric manipulating the luck of their own as well as those around them through their connection with their god.
#
# Here is a link to the subclass in case the picture isn't easy to read: [https://homebrewery.naturalcrit.com/share/MhTK9\_7zHuB6](https://homebrewery.naturalcrit.com/share/MhTK9_7zHuB6)
#
# When I say partly inspired by Hollow Knight, I mean *very* partly. Most of the inspiration was "bug race" and "mantises have a warrior culture."
#
# My favorite idea I've had from this is an arachne artificer that wants to map out the Up Above named Webster.
#
# All updates found [here](https://www.gmbinder.com/share/-MVy-6VQ01Ft9YsPWZ15)
#
# EDIT LOG
#
# Coleo's Horn now has knocking prone as a separate action
#
# Placed time limit on Web Spinner. Rope and nets made by you now last for 24 hours, since spiders typically tear down and rebuild their webs daily
#
# Acrid Chirper now replaces verbal components rather than material and can be used for all spells, not just bard
#
# Added Jumping Arachne variant based on [jumping spiders](https://en.wikipedia.org/wiki/Jumping_spider)
#
# Added Flower Manten variant based on [flower mantises](https://en.wikipedia.org/wiki/Flower_mantis)
#
# Note: The class currently just uses the Warlock spell list, but if anyone has recommendations as to spells that should be added or omitted for this class please share!
#
# Additionally, this class is best suited for experienced players looking for something with a new feel. I wouldn't recommend it if you're just starting out since its abilities a lot to keep track of and relatively complex.
#
# Also, this is my first full homebrew, so if you have any suggestions they are welcome!
#
# PDF link: [https://homebrewery.naturalcrit.com/share/leDBql2umJCU](https://homebrewery.naturalcrit.com/share/leDBql2umJCU)
#
# Hi everyone! This a subclass that I've been thinking of for a while (although I'm not sure if the name is my favorite at the moment). The subclass started off as a non-evil version of the Oathbreaker called the Oathless, but I felt the oath they got kind of completely contradicted it.
#
# The subclass is mostly focused on buffs and more defensive features. It's not looking to change how the class is played entirely but is more focused on keeping you in the fight for as long as possible. If there are any suggestions you'd like to make, I'm gladly open to hearing them as I haven't homebrewed pretty much anything outside the table I play at.
#
# GM Binder link here: [https://www.gmbinder.com/share/-MVxOdThHWkEdg07s5yH](https://www.gmbinder.com/share/-MVxOdThHWkEdg07s5yH)
#
# Survey [here](https://docs.google.com/forms/d/e/1FAIpQLSevhdDk4WvuY8WLm8rKfQ0XDMPqDhCqn-HVm5kyhASjZJtoeQ/viewform). You can also view on [GM Binder](https://www.gmbinder.com/share/-MVJujifYnF1PBcZg2yu)!
#
# [https://homebrewery.naturalcrit.com/share/5L4tFD0\_a0Kt](https://homebrewery.naturalcrit.com/share/5L4tFD0_a0Kt) Oops, here you go. :)
#
# [Link to my Homebrewer Version](https://homebrewery.naturalcrit.com/edit/gUo-uGIukIe-)

# %% [markdown]
# # Extracting the GMBinder and/or Homebrewery links
#
# We can see we have some different varieties of potentially useful links, including /share/ and /edit/ links. There are also some from unrelated domains (Google Docs, Wikipedia articles, etc.) and some direct links to PDF files that lack the HTML source we want to collect.
#
# We also have three varieties of link text:
#
# ## Raw links
# URLs with no special formating around them.
# > <pre>Gmbinder Link: https://www.gmbinder.com/share/-MW5xKc1QPj4TXEgBzQm</pre>
#
# ## Markdown links
# These take the form of a display text portion in brackets immediately followed by a URL in parenthesis.
# > <pre>[Display text](url)</pre>
#
# Moreover, in some cases, the display text is also a url and in at least one case early on the url is incorrect in the display text portion, but correct in the actual url segment of the link code.
#
# > <pre>[https://homebrewery.naturalcrit.com/share/MhTK9\_7zHuB6](https://homebrewery.naturalcrit.com/share/MhTK9_7zHuB6)</pre>
#
# Since, the url portion is more likely to be correct in most cases, we'll go exclusively with raw links and the (url) portion of markdown code.
#
# To do this we can use a set of regular expressions. After a few trial and errors, I arrived at the following:
#
# ### Homebrewery
# > <pre>?:https?:\/\/)?(?:www\.)?homebrewery\.naturalcrit\.com\/[\w\-][\w\-]*\/?[\w\-]*\/?[\w\-]*</pre>
#
# ### GMBinder
# > <pre>(?:https?:\/\/)?(?:www\.)?gmbinder\.com\/[\w\-][\w\-]*\/?[\w\-]*\/?[\w\-]*[\s\)]</pre>

# %%
cmts_df['url'] = cmts_df['body'].str.findall(r'[\s\(](?:https?:\/\/)?(?:www\.)?homebrewery\.naturalcrit\.com\/[\w\-][\w\-]*\/?[\w\-]*\/?[\w\-]*[\s\\)]|[\s\(](?:https?:\/\/)?(?:www\.)?gmbinder\.com\/[\w\-][\w\-]*\/?[\w\-]*\/?[\w\-]*[\s\)]')
for i in cmts_df['url'][0:14]:
    print(i)
# Out:
# [' https://www.gmbinder.com/share/-MW5xKc1QPj4TXEgBzQm\n']
# ['(https://www.gmbinder.com/share/-MVeY68xfxI2MrESmAq0)', '(https://www.gmbinder.com/share/-M90l_C5MPCYvWvO1mpD)']
# ['(https://homebrewery.naturalcrit.com/share/MhTK9_7zHuB6)']
# ['(https://www.gmbinder.com/share/-MVy-6VQ01Ft9YsPWZ15)']
# ['(https://homebrewery.naturalcrit.com/share/leDBql2umJCU)']
# ['(https://www.gmbinder.com/share/-MVxOdThHWkEdg07s5yH)']
# ['(https://www.gmbinder.com/share/-MVJujifYnF1PBcZg2yu)']
# ['(https://homebrewery.naturalcrit.com/share/5L4tFD0_a0Kt)']
# ['(https://homebrewery.naturalcrit.com/edit/gUo-uGIukIe-)']
# ['(https://www.gmbinder.com/share/-MVm5LgT_HqPPsPa8Bgd)']
# []
# ['(https://www.gmbinder.com/share/-MU8f5FYNfXKKi7QkQXQ)', '(https://www.gmbinder.com/profile/FrostBladestorm)', '(https://www.gmbinder.com/profile/FrostBladestorm)']
# ['(https://homebrewery.naturalcrit.com/share/1X_0vq1WBXrQq2EeNZ1CMOeTVt5PxyWmSLs3wWVRyBTEy)']
# ['(https://www.gmbinder.com/share/-MHtvbKTKQu8Faoz4YJp)']

# %% [markdown]
# # Final cleaning steps...
#
# As expected, some entries have multiple urls, while others now lack any entries.
#
# Many of our strings also having some hanging portions at the ends from our Regex expression:
# * '('
# * ')'
# * '\n'
# * ' '
#
# For our final data, we'd like to get everything in a format where each row represets one URL rather than one post and each URL is unique and has been cleaned.
#
# Lastly, we'll remove anything with 'profile' or 'pdf' in the url, as these URLs require significantly more processing to handle and would not be worth the effort (especially the PDFs)
#
# Luckily, we have a few convient tools at our disposal, so we will takle this in the following manner:
#
# 1) Expand each entry into multiple rows for each URL in the dataset. To do this we will use Pandas' .explode() function designed for this very purpose.
#
# 2) Remove rows that are now empty (i.e. posts that only contained direct links to the homebrewery/gmbinder homepage) by dropping NA values
#
# 3) Each each individual string to remove the extraneous portions left over using the map function.
#
# 4) Remove duplicates using the drop_duplicates() function in Pandas.
#
# 5) Lastly, we'll remove any rows that contain the string 'pdf' or 'profile'

# %%
cmts_df = cmts_df.explode('url')
cmts_df = cmts_df.dropna()
cmts_df['url'] = cmts_df['url'].map(lambda x : x.strip('(').strip(')').strip('\n').strip(' '))
cmts_df.drop_duplicates(subset=['url'],keep='first',inplace=True)
cmts_df = cmts_df[cmts_df['url'].str.contains('pdf') == False]
cmts_df = cmts_df[cmts_df['url'].str.contains('profile') == False]
cmts_df = cmts_df[cmts_df['url'].str.contains('edit') == False]
cmts_df.reindex()
cmts_df.head(25)
# Out:
#    comment_id post_id                                               body  \
# 0     grfoljw  m86g8n  Here's the first in a project I've been workin...
# 1     grf99dk  m7y9rp  This subclass has features requiring the *Psyc...
# 1     grf99dk  m7y9rp  This subclass has features requiring the *Psyc...
# 2     grd344y  m7s097  Hello, everyone!  Hoping to get some serious c...
# 3     gr9amwd  m75i2f  When I say partly inspired by Hollow Knight, I...
# 4     gr99ryw  m75bsj  Note: The class currently just uses the Warloc...
# 5     gr8y8lg  m73c7l  Hi everyone! This a subclass that I've been th...
# 6     gr67wsv  m6kq63  Survey [here](https://docs.google.com/forms/d/...
# 7     gr577dw  m68lk9  [https://homebrewery.naturalcrit.com/share/5L4...
# 9     gqyg3ll  m56sxy  I think most people here know by now that WOTC...
# 11    gqvj5b1  m4pee6  Hey everyone! Barbarian isn't a class I know p...
# 12    gqtr7oo  m4d83w  First I would like to say this is my second tr...
# 13    gqrza8e  m3unc3  Here are some supportive blood curses from u/r...
# 14    gqp9dpa  m3kg2v  Hi everyone! I'm back today with another homeb...
# 15    gqou6wz  m3i0na  GM Binder: [https://www.gmbinder.com/share/-MV...
# 16    gqnxs45  m3bmzj   Hey y'all here is a first draft version of my...
# 17    gqn8spv  m36y3k  This is a simple cantrip that intends to bette...
# 18    gr15dvs  m32ca4  [Homebrewery Link](https://homebrewery.natural...
# 19    gqgrl22  m22d2b  All updated versions found [here](https://www....
# 20    gqfcmis  m1srgj  [Homebrewery Link](https://homebrewery.natural...
# 22    gqd97yr  m1f4wj  Homebrewery link can be found [here](https://h...
# 23    gqcr5nj  m1c1lb  This is my first homebrew and my first time po...
# 24    gqcpyre  m1bw7b  Thanks for checking this out! Something bigger...
# 26    gqdegdc  m0sr48  Here's the [homebrewery link](https://homebrew...
# 27    gq9f1t7  m0qfzy  This is actually one of my favorite subclasses...
#
#                 sub                                         post_title  \
# 0   UnearthedArcana          Variant Hobgoblin - Emporium of the Races
# 1   UnearthedArcana  Bard - College of Forgotten Echoes; a spiritua...
# 1   UnearthedArcana  Bard - College of Forgotten Echoes; a spiritua...
# 2   UnearthedArcana  Fortune Domain - 5e Cleric Subclass (CONSTRUCT...
# 3   UnearthedArcana  Bugfolk, a Race of Creepy-Crawlies Partly Insp...
# 4   UnearthedArcana  The Eldritch Brawler | Class with a unique, fa...
# 5   UnearthedArcana  Oath of Self - A Paladin subclass for those wh...
# 6   UnearthedArcana                       Ranger - Crystalline Trapper
# 7   UnearthedArcana        Greywatcher: An Advanced Demon Hunter Class
# 9   UnearthedArcana                            Fairy Race Remixed (5e)
# 11  UnearthedArcana  Barbarian: Path of the Iron Fist - Strong arm ...
# 12  UnearthedArcana  The Merchant a fake god on a material plane an...
# 13  UnearthedArcana                       Support Focused Blood Curses
# 14  UnearthedArcana  Your Bard can walk the dog and rock the baby w...
# 15  UnearthedArcana  Half-Undead: My first ever Homebrew Race. Feed...
# 16  UnearthedArcana  Conclave of the Trapper: Know your enemy with ...
# 17  UnearthedArcana  Toggle: Turn your magic items off and on again...
# 18  UnearthedArcana  Forgemaster Artificer v2.0 - a Castlevania-Ins...
# 19  UnearthedArcana  May the Odds be Ever in Your Favor: The Fate D...
# 20  UnearthedArcana   Egg's Group Spellcasting System - Spell Charging
# 22  UnearthedArcana                   Sorcerer Subclass: Fiendish Soul
# 23  UnearthedArcana                 The Tomb Guard - My first homebrew
# 24  UnearthedArcana  (Artificer) Charioteer: Take Joy-Rides in a Ve...
# 26  UnearthedArcana  Chromatic Knight | Empower your attacks with p...
# 27  UnearthedArcana              Propehcy Domain: Oracle of the Divine
#
#     post_flair                                                url
# 0         Race  https://www.gmbinder.com/share/-MW5xKc1QPj4TXE...
# 1     Subclass  https://www.gmbinder.com/share/-MVeY68xfxI2MrE...
# 1     Subclass  https://www.gmbinder.com/share/-M90l_C5MPCYvWv...
# 2     Subclass  https://homebrewery.naturalcrit.com/share/MhTK...
# 3         Race  https://www.gmbinder.com/share/-MVy-6VQ01Ft9Ys...
# 4        Class  https://homebrewery.naturalcrit.com/share/leDB...
# 5     Subclass  https://www.gmbinder.com/share/-MVxOdThHWkEdg0...
# 6     Subclass  https://www.gmbinder.com/share/-MVJujifYnF1PBc...
# 7        Class  https://homebrewery.naturalcrit.com/share/5L4t...
# 9         Race  https://www.gmbinder.com/share/-MVm5LgT_HqPPsP...
# 11    Subclass  https://www.gmbinder.com/share/-MU8f5FYNfXKKi7...
# 12  Compendium  https://homebrewery.naturalcrit.com/share/1X_0...
# 13     Feature  https://www.gmbinder.com/share/-MHtvbKTKQu8Fao...
# 14    Subclass  https://www.gmbinder.com/share/-MVZhkDeIhwoI-U...
# 15        Race  https://www.gmbinder.com/share/-MVaWbb-hJs6PL8...
# 16    Subclass  https://homebrewery.naturalcrit.com/share/nOUx...
# 17       Spell  https://homebrewery.naturalcrit.com/share/1cZA...
# 18    Subclass  https://homebrewery.naturalcrit.com/share/L2iB...
# 19    Subclass  https://www.gmbinder.com/share/-MUkyzZnKIvrRyY...
# 20    Mechanic  https://homebrewery.naturalcrit.com/share/1imm...
# 22    Subclass  https://homebrewery.naturalcrit.com/share/DTdv...
# 23        Race  https://www.gmbinder.com/share/-MUxyD0cjgpml2w...
# 24    Subclass  https://www.gmbinder.com/share/-MRedPQcFXnrW4Q...
# 26    Subclass  https://homebrewery.naturalcrit.com/share/1SYG...
# 27    Subclass  https://www.gmbinder.com/share/-MPzc9hzcO_Lh7u...

# %% [markdown]
# # Collect Markdown/Source Code
#
# Next, we'll import the post data and collect the mixed html/css/markdown-style source code used by Homebrewery/GMBinder.
#
# For this, I've defined two functions in dnd_scraper_tools that I'll be importing.
#
# The first function simply checks for a source code button. This seems to be standard on Homebrewery, but can be optionally disabled on GMBinder.
#
# In that event, we'll try to get the cleanest text we can from the HTML available on the main display page, so the function will return the original URL if it can't find a button. This is done only for the GMBinder links, as Homebrewery's mcontained directain display page is rendered by React JS and collecting the text via BeautifulSoup is not possible. My initial exploration of the links suggests that this does not occur. If it does, the script will return an value of None that we can later filter out.
#
# ##### Note, I performed some manual curation of the post data to add UnearthedArcana style descriptive flair tags to the DnDHomebrew posts, that way this datset is initially complete with respect to that column.

# %%
from dnd_scraper_tools import grab_src_url, collect_text, remove_html

posts_df = pd.read_csv(posts_csv,sep=',',index_col=0)

posts_df = posts_df[posts_df['url'].str.contains('pdf') == False]
posts_df = posts_df[posts_df['url'].str.contains('profile') == False]
posts_df = posts_df[posts_df['url'].str.contains('edit') == False]

# %%
posts_df.head(10)
# Out:
#   post_id                                              title  \
# 0  m7s6jd  [5E] Metamorph, a (hopefully) balanced substit...
# 1  m7ezuy  Cute Magical Critter Warlock Patron | Sign a c...
# 2  m73s8f                    Akkator's Compendium of Classes
# 3  m71mtw  Order of the Thereon-Blood Hunter subclass v 1.01
# 4  m6t7k8  Selakyn - a Race of Nomadic Shark People, stil...
# 5  m6odpv  HD and XP as Currency? Thoughts and critiques ...
# 6  m6o99q  Satyr Reimagined! Now with 3 new subraces, fea...
# 7  m6h3jr  Sealed Dragon v1.4 | A Dragon Sealed Inside a ...
# 8  m5xg2a  Taking a swing at my own Ranger revision, with...
# 9  m5tt9a  Way of the Coiled Cobra | Dodge and Strike wit...
#
#                                                  url              sub  score  \
# 0  https://homebrewery.naturalcrit.com/share/tpKj...  UnearthedArcana      2
# 1  https://www.gmbinder.com/share/-MT4G-aRMFvYwYw...  UnearthedArcana     21
# 2  https://homebrewery.naturalcrit.com/share/gvVS...  UnearthedArcana      5
# 3  https://homebrewery.naturalcrit.com/share/1ScB...  UnearthedArcana      3
# 4  https://homebrewery.naturalcrit.com/share/p-k2...  UnearthedArcana      4
# 5  https://homebrewery.naturalcrit.com/share/1fCq...  UnearthedArcana      2
# 6  https://homebrewery.naturalcrit.com/share/vxyP...  UnearthedArcana      1
# 7  https://homebrewery.naturalcrit.com/share/SRjD...  UnearthedArcana      5
# 8  https://www.gmbinder.com/share/-MTpa3ordIxC74W...  UnearthedArcana      0
# 9  https://www.gmbinder.com/share/-MUKsI6Ft8OQgYe...  UnearthedArcana     12
#
#         flair  upvote_ratio
# 0       Class          0.75
# 1    Subclass          0.93
# 2  Compendium          1.00
# 3    Subclass          1.00
# 4        Race          1.00
# 5    Mechanic          1.00
# 6        Race          0.60
# 7       Class          0.70
# 8       Class          0.40
# 9    Subclass          1.00

# %%
posts_df['src_url'] = posts_df['url'].map(grab_src_url)
posts_df.head(10)
# Out:
#   post_id                                              title  \
# 0  m7s6jd  [5E] Metamorph, a (hopefully) balanced substit...
# 1  m7ezuy  Cute Magical Critter Warlock Patron | Sign a c...
# 2  m73s8f                    Akkator's Compendium of Classes
# 3  m71mtw  Order of the Thereon-Blood Hunter subclass v 1.01
# 4  m6t7k8  Selakyn - a Race of Nomadic Shark People, stil...
# 5  m6odpv  HD and XP as Currency? Thoughts and critiques ...
# 6  m6o99q  Satyr Reimagined! Now with 3 new subraces, fea...
# 7  m6h3jr  Sealed Dragon v1.4 | A Dragon Sealed Inside a ...
# 8  m5xg2a  Taking a swing at my own Ranger revision, with...
# 9  m5tt9a  Way of the Coiled Cobra | Dodge and Strike wit...
#
#                                                  url              sub  score  \
# 0  https://homebrewery.naturalcrit.com/share/tpKj...  UnearthedArcana      2
# 1  https://www.gmbinder.com/share/-MT4G-aRMFvYwYw...  UnearthedArcana     21
# 2  https://homebrewery.naturalcrit.com/share/gvVS...  UnearthedArcana      5
# 3  https://homebrewery.naturalcrit.com/share/1ScB...  UnearthedArcana      3
# 4  https://homebrewery.naturalcrit.com/share/p-k2...  UnearthedArcana      4
# 5  https://homebrewery.naturalcrit.com/share/1fCq...  UnearthedArcana      2
# 6  https://homebrewery.naturalcrit.com/share/vxyP...  UnearthedArcana      1
# 7  https://homebrewery.naturalcrit.com/share/SRjD...  UnearthedArcana      5
# 8  https://www.gmbinder.com/share/-MTpa3ordIxC74W...  UnearthedArcana      0
# 9  https://www.gmbinder.com/share/-MUKsI6Ft8OQgYe...  UnearthedArcana     12
#
#         flair  upvote_ratio                                            src_url
# 0       Class          0.75  https://homebrewery.naturalcrit.com/source/tpK...
# 1    Subclass          0.93  https://www.gmbinder.com/share/-MT4G-aRMFvYwYw...
# 2  Compendium          1.00  https://homebrewery.naturalcrit.com/source/gvV...
# 3    Subclass          1.00  https://homebrewery.naturalcrit.com/source/1Sc...
# 4        Race          1.00  https://homebrewery.naturalcrit.com/source/p-k...
# 5    Mechanic          1.00  https://homebrewery.naturalcrit.com/source/1fC...
# 6        Race          0.60  https://homebrewery.naturalcrit.com/source/vxy...
# 7       Class          0.70  https://homebrewery.naturalcrit.com/source/SRj...
# 8       Class          0.40  https://www.gmbinder.com/share/-MTpa3ordIxC74W...
# 9    Subclass          1.00  https://www.gmbinder.com/share/-MUKsI6Ft8OQgYe...

# %%
cmts_df['src_url'] = cmts_df['url'].map(grab_src_url)
cmts_df.head(10)
# Out:
#   comment_id post_id                                               body  \
# 0    grfoljw  m86g8n  Here's the first in a project I've been workin...
# 1    grf99dk  m7y9rp  This subclass has features requiring the *Psyc...
# 1    grf99dk  m7y9rp  This subclass has features requiring the *Psyc...
# 2    grd344y  m7s097  Hello, everyone!  Hoping to get some serious c...
# 3    gr9amwd  m75i2f  When I say partly inspired by Hollow Knight, I...
# 4    gr99ryw  m75bsj  Note: The class currently just uses the Warloc...
# 5    gr8y8lg  m73c7l  Hi everyone! This a subclass that I've been th...
# 6    gr67wsv  m6kq63  Survey [here](https://docs.google.com/forms/d/...
# 7    gr577dw  m68lk9  [https://homebrewery.naturalcrit.com/share/5L4...
# 9    gqyg3ll  m56sxy  I think most people here know by now that WOTC...
#
#                sub                                         post_title  \
# 0  UnearthedArcana          Variant Hobgoblin - Emporium of the Races
# 1  UnearthedArcana  Bard - College of Forgotten Echoes; a spiritua...
# 1  UnearthedArcana  Bard - College of Forgotten Echoes; a spiritua...
# 2  UnearthedArcana  Fortune Domain - 5e Cleric Subclass (CONSTRUCT...
# 3  UnearthedArcana  Bugfolk, a Race of Creepy-Crawlies Partly Insp...
# 4  UnearthedArcana  The Eldritch Brawler | Class with a unique, fa...
# 5  UnearthedArcana  Oath of Self - A Paladin subclass for those wh...
# 6  UnearthedArcana                       Ranger - Crystalline Trapper
# 7  UnearthedArcana        Greywatcher: An Advanced Demon Hunter Class
# 9  UnearthedArcana                            Fairy Race Remixed (5e)
#
#   post_flair                                                url  \
# 0       Race  https://www.gmbinder.com/share/-MW5xKc1QPj4TXE...
# 1   Subclass  https://www.gmbinder.com/share/-MVeY68xfxI2MrE...
# 1   Subclass  https://www.gmbinder.com/share/-M90l_C5MPCYvWv...
# 2   Subclass  https://homebrewery.naturalcrit.com/share/MhTK...
# 3       Race  https://www.gmbinder.com/share/-MVy-6VQ01Ft9Ys...
# 4      Class  https://homebrewery.naturalcrit.com/share/leDB...
# 5   Subclass  https://www.gmbinder.com/share/-MVxOdThHWkEdg0...
# 6   Subclass  https://www.gmbinder.com/share/-MVJujifYnF1PBc...
# 7      Class  https://homebrewery.naturalcrit.com/share/5L4t...
# 9       Race  https://www.gmbinder.com/share/-MVm5LgT_HqPPsP...
#
#                                              src_url
# 0  https://www.gmbinder.com/share/-MW5xKc1QPj4TXE...
# 1  https://www.gmbinder.com/share/-MVeY68xfxI2MrE...
# 1  https://www.gmbinder.com/share/-M90l_C5MPCYvWv...
# 2  https://homebrewery.naturalcrit.com/source/MhT...
# 3  https://www.gmbinder.com/share/-MVy-6VQ01Ft9Ys...
# 4  https://homebrewery.naturalcrit.com/source/leD...
# 5  https://www.gmbinder.com/share/-MVxOdThHWkEdg0...
# 6  https://www.gmbinder.com/share/-MVJujifYnF1PBc...
# 7  https://homebrewery.naturalcrit.com/source/5L4...
# 9  https://www.gmbinder.com/share/-MVm5LgT_HqPPsP...

# %%
cmts_df['Text'] = cmts_df['src_url'].map(collect_text)
posts_df['Text'] = posts_df['src_url'].map(collect_text)

# %%
cmts_df.head(10)
# Out:
#   comment_id post_id                                               body  \
# 0    grfoljw  m86g8n  Here's the first in a project I've been workin...
# 1    grf99dk  m7y9rp  This subclass has features requiring the *Psyc...
# 1    grf99dk  m7y9rp  This subclass has features requiring the *Psyc...
# 2    grd344y  m7s097  Hello, everyone!  Hoping to get some serious c...
# 3    gr9amwd  m75i2f  When I say partly inspired by Hollow Knight, I...
# 4    gr99ryw  m75bsj  Note: The class currently just uses the Warloc...
# 5    gr8y8lg  m73c7l  Hi everyone! This a subclass that I've been th...
# 6    gr67wsv  m6kq63  Survey [here](https://docs.google.com/forms/d/...
# 7    gr577dw  m68lk9  [https://homebrewery.naturalcrit.com/share/5L4...
# 9    gqyg3ll  m56sxy  I think most people here know by now that WOTC...
#
#                sub                                         post_title  \
# 0  UnearthedArcana          Variant Hobgoblin - Emporium of the Races
# 1  UnearthedArcana  Bard - College of Forgotten Echoes; a spiritua...
# 1  UnearthedArcana  Bard - College of Forgotten Echoes; a spiritua...
# 2  UnearthedArcana  Fortune Domain - 5e Cleric Subclass (CONSTRUCT...
# 3  UnearthedArcana  Bugfolk, a Race of Creepy-Crawlies Partly Insp...
# 4  UnearthedArcana  The Eldritch Brawler | Class with a unique, fa...
# 5  UnearthedArcana  Oath of Self - A Paladin subclass for those wh...
# 6  UnearthedArcana                       Ranger - Crystalline Trapper
# 7  UnearthedArcana        Greywatcher: An Advanced Demon Hunter Class
# 9  UnearthedArcana                            Fairy Race Remixed (5e)
#
#   post_flair                                                url  \
# 0       Race  https://www.gmbinder.com/share/-MW5xKc1QPj4TXE...
# 1   Subclass  https://www.gmbinder.com/share/-MVeY68xfxI2MrE...
# 1   Subclass  https://www.gmbinder.com/share/-M90l_C5MPCYvWv...
# 2   Subclass  https://homebrewery.naturalcrit.com/share/MhTK...
# 3       Race  https://www.gmbinder.com/share/-MVy-6VQ01Ft9Ys...
# 4      Class  https://homebrewery.naturalcrit.com/share/leDB...
# 5   Subclass  https://www.gmbinder.com/share/-MVxOdThHWkEdg0...
# 6   Subclass  https://www.gmbinder.com/share/-MVJujifYnF1PBc...
# 7      Class  https://homebrewery.naturalcrit.com/share/5L4t...
# 9       Race  https://www.gmbinder.com/share/-MVm5LgT_HqPPsP...
#
#                                              src_url  \
# 0  https://www.gmbinder.com/share/-MW5xKc1QPj4TXE...
# 1  https://www.gmbinder.com/share/-MVeY68xfxI2MrE...
# 1  https://www.gmbinder.com/share/-M90l_C5MPCYvWv...
# 2  https://homebrewery.naturalcrit.com/source/MhT...
# 3  https://www.gmbinder.com/share/-MVy-6VQ01Ft9Ys...
# 4  https://homebrewery.naturalcrit.com/source/leD...
# 5  https://www.gmbinder.com/share/-MVxOdThHWkEdg0...
# 6  https://www.gmbinder.com/share/-MVJujifYnF1PBc...
# 7  https://homebrewery.naturalcrit.com/source/5L4...
# 9  https://www.gmbinder.com/share/-MVm5LgT_HqPPsP...
#
#                                                 Text
# 0  <img\nsrc='https://images.squarespace-cdn.com/...
# 1  <style>\n  .phb#p2:after { display:none; }\n  ...
# 1  <style>\n    .phb:after {\n        display: no...
# 2  ### Fortune Domain\nClerics of the Fortune dom...
# 3  <style>\n/* Background */\n  .phb{ background-...
# 4  <div>\n# Eldritch Brawler\n<div class='pageNum...
# 5  ### Oath of Self\n\nAn Oath of Self paladin is...
# 6  \n    \n  \n  \n    \n    \n    \n    \n      ...
# 7  <style>\n  .phb#p1{ text-align:center; }\n  .p...
# 9  # Fairies - A remixed race (v1.1)\n\nFairies h...

# %%
posts_df.head(10)
# Out:
#   post_id                                              title  \
# 0  m7s6jd  [5E] Metamorph, a (hopefully) balanced substit...
# 1  m7ezuy  Cute Magical Critter Warlock Patron | Sign a c...
# 2  m73s8f                    Akkator's Compendium of Classes
# 3  m71mtw  Order of the Thereon-Blood Hunter subclass v 1.01
# 4  m6t7k8  Selakyn - a Race of Nomadic Shark People, stil...
# 5  m6odpv  HD and XP as Currency? Thoughts and critiques ...
# 6  m6o99q  Satyr Reimagined! Now with 3 new subraces, fea...
# 7  m6h3jr  Sealed Dragon v1.4 | A Dragon Sealed Inside a ...
# 8  m5xg2a  Taking a swing at my own Ranger revision, with...
# 9  m5tt9a  Way of the Coiled Cobra | Dodge and Strike wit...
#
#                                                  url              sub  score  \
# 0  https://homebrewery.naturalcrit.com/share/tpKj...  UnearthedArcana      2
# 1  https://www.gmbinder.com/share/-MT4G-aRMFvYwYw...  UnearthedArcana     21
# 2  https://homebrewery.naturalcrit.com/share/gvVS...  UnearthedArcana      5
# 3  https://homebrewery.naturalcrit.com/share/1ScB...  UnearthedArcana      3
# 4  https://homebrewery.naturalcrit.com/share/p-k2...  UnearthedArcana      4
# 5  https://homebrewery.naturalcrit.com/share/1fCq...  UnearthedArcana      2
# 6  https://homebrewery.naturalcrit.com/share/vxyP...  UnearthedArcana      1
# 7  https://homebrewery.naturalcrit.com/share/SRjD...  UnearthedArcana      5
# 8  https://www.gmbinder.com/share/-MTpa3ordIxC74W...  UnearthedArcana      0
# 9  https://www.gmbinder.com/share/-MUKsI6Ft8OQgYe...  UnearthedArcana     12
#
#         flair  upvote_ratio  \
# 0       Class          0.75
# 1    Subclass          0.93
# 2  Compendium          1.00
# 3    Subclass          1.00
# 4        Race          1.00
# 5    Mechanic          1.00
# 6        Race          0.60
# 7       Class          0.70
# 8       Class          0.40
# 9    Subclass          1.00
#
#                                              src_url  \
# 0  https://homebrewery.naturalcrit.com/source/tpK...
# 1  https://www.gmbinder.com/share/-MT4G-aRMFvYwYw...
# 2  https://homebrewery.naturalcrit.com/source/gvV...
# 3  https://homebrewery.naturalcrit.com/source/1Sc...
# 4  https://homebrewery.naturalcrit.com/source/p-k...
# 5  https://homebrewery.naturalcrit.com/source/1fC...
# 6  https://homebrewery.naturalcrit.com/source/vxy...
# 7  https://homebrewery.naturalcrit.com/source/SRj...
# 8  https://www.gmbinder.com/share/-MTpa3ordIxC74W...
# 9  https://www.gmbinder.com/share/-MUKsI6Ft8OQgYe...
#
#                                                 Text
# 0  # Metamorph\nAn eldarly human sits locked in c...
# 1  ## Otherworldly Patron: Cute Magical Critter (...
# 2  # Akkator's Compendium of Classes\n\nWithin th...
# 3  ## Blood Hunter Order\n<img \n  src='https://p...
# 4  ## The Selakyn\nSelakyns, also known as Shark ...
# 5  ## Hit Dice and Experience Point Currency\n*Du...
# 6  # The Satyr / Faun \nThe Satyr are a race of j...
# 7  <div class='classTable wide'>\n##### The Seale...
# 8  # Ranger\n## Class Features\nAs a Ranger, you ...
# 9  ### Way of the Coiled Cobra\n\nMonks of the Wa...

# %% [markdown]
# # Removing residual HTML
# A quick scan reveals that some HTML tags in the source text (extra styling elements, etc) did not get removed. Let's strip all of the HTML one more time.

# %%
cmts_df['Text'] = cmts_df['Text'].map(remove_html)
posts_df['Text'] = posts_df['Text'].map(remove_html)

# %%
posts_df.head(10)
# Out:
#   post_id                                              title  \
# 0  m7s6jd  [5E] Metamorph, a (hopefully) balanced substit...
# 1  m7ezuy  Cute Magical Critter Warlock Patron | Sign a c...
# 2  m73s8f                    Akkator's Compendium of Classes
# 3  m71mtw  Order of the Thereon-Blood Hunter subclass v 1.01
# 4  m6t7k8  Selakyn - a Race of Nomadic Shark People, stil...
# 5  m6odpv  HD and XP as Currency? Thoughts and critiques ...
# 6  m6o99q  Satyr Reimagined! Now with 3 new subraces, fea...
# 7  m6h3jr  Sealed Dragon v1.4 | A Dragon Sealed Inside a ...
# 8  m5xg2a  Taking a swing at my own Ranger revision, with...
# 9  m5tt9a  Way of the Coiled Cobra | Dodge and Strike wit...
#
#                                                  url              sub  score  \
# 0  https://homebrewery.naturalcrit.com/share/tpKj...  UnearthedArcana      2
# 1  https://www.gmbinder.com/share/-MT4G-aRMFvYwYw...  UnearthedArcana     21
# 2  https://homebrewery.naturalcrit.com/share/gvVS...  UnearthedArcana      5
# 3  https://homebrewery.naturalcrit.com/share/1ScB...  UnearthedArcana      3
# 4  https://homebrewery.naturalcrit.com/share/p-k2...  UnearthedArcana      4
# 5  https://homebrewery.naturalcrit.com/share/1fCq...  UnearthedArcana      2
# 6  https://homebrewery.naturalcrit.com/share/vxyP...  UnearthedArcana      1
# 7  https://homebrewery.naturalcrit.com/share/SRjD...  UnearthedArcana      5
# 8  https://www.gmbinder.com/share/-MTpa3ordIxC74W...  UnearthedArcana      0
# 9  https://www.gmbinder.com/share/-MUKsI6Ft8OQgYe...  UnearthedArcana     12
#
#         flair  upvote_ratio  \
# 0       Class          0.75
# 1    Subclass          0.93
# 2  Compendium          1.00
# 3    Subclass          1.00
# 4        Race          1.00
# 5    Mechanic          1.00
# 6        Race          0.60
# 7       Class          0.70
# 8       Class          0.40
# 9    Subclass          1.00
#
#                                              src_url  \
# 0  https://homebrewery.naturalcrit.com/source/tpK...
# 1  https://www.gmbinder.com/share/-MT4G-aRMFvYwYw...
# 2  https://homebrewery.naturalcrit.com/source/gvV...
# 3  https://homebrewery.naturalcrit.com/source/1Sc...
# 4  https://homebrewery.naturalcrit.com/source/p-k...
# 5  https://homebrewery.naturalcrit.com/source/1fC...
# 6  https://homebrewery.naturalcrit.com/source/vxy...
# 7  https://homebrewery.naturalcrit.com/source/SRj...
# 8  https://www.gmbinder.com/share/-MTpa3ordIxC74W...
# 9  https://www.gmbinder.com/share/-MUKsI6Ft8OQgYe...
#
#                                                 Text
# 0  # Metamorph\nAn eldarly human sits locked in c...
# 1  ## Otherworldly Patron: Cute Magical Critter (...
# 2  # Akkator's Compendium of Classes\n\nWithin th...
# 3  ## Blood Hunter Order\n\nCredit: Jikayen\n####...
# 4  ## The Selakyn\nSelakyns, also known as Shark ...
# 5  ## Hit Dice and Experience Point Currency\n*Du...
# 6  # The Satyr / Faun \nThe Satyr are a race of j...
# 7  \n##### The Sealed Dragon\n| Level | Proficien...
# 8  # Ranger\n## Class Features\nAs a Ranger, you ...
# 9  ### Way of the Coiled Cobra\n\nMonks of the Wa...

# %%
cmts_df.head(10)
# Out:
#   comment_id post_id                                               body  \
# 0    grfoljw  m86g8n  Here's the first in a project I've been workin...
# 1    grf99dk  m7y9rp  This subclass has features requiring the *Psyc...
# 1    grf99dk  m7y9rp  This subclass has features requiring the *Psyc...
# 2    grd344y  m7s097  Hello, everyone!  Hoping to get some serious c...
# 3    gr9amwd  m75i2f  When I say partly inspired by Hollow Knight, I...
# 4    gr99ryw  m75bsj  Note: The class currently just uses the Warloc...
# 5    gr8y8lg  m73c7l  Hi everyone! This a subclass that I've been th...
# 6    gr67wsv  m6kq63  Survey [here](https://docs.google.com/forms/d/...
# 7    gr577dw  m68lk9  [https://homebrewery.naturalcrit.com/share/5L4...
# 9    gqyg3ll  m56sxy  I think most people here know by now that WOTC...
#
#                sub                                         post_title  \
# 0  UnearthedArcana          Variant Hobgoblin - Emporium of the Races
# 1  UnearthedArcana  Bard - College of Forgotten Echoes; a spiritua...
# 1  UnearthedArcana  Bard - College of Forgotten Echoes; a spiritua...
# 2  UnearthedArcana  Fortune Domain - 5e Cleric Subclass (CONSTRUCT...
# 3  UnearthedArcana  Bugfolk, a Race of Creepy-Crawlies Partly Insp...
# 4  UnearthedArcana  The Eldritch Brawler | Class with a unique, fa...
# 5  UnearthedArcana  Oath of Self - A Paladin subclass for those wh...
# 6  UnearthedArcana                       Ranger - Crystalline Trapper
# 7  UnearthedArcana        Greywatcher: An Advanced Demon Hunter Class
# 9  UnearthedArcana                            Fairy Race Remixed (5e)
#
#   post_flair                                                url  \
# 0       Race  https://www.gmbinder.com/share/-MW5xKc1QPj4TXE...
# 1   Subclass  https://www.gmbinder.com/share/-MVeY68xfxI2MrE...
# 1   Subclass  https://www.gmbinder.com/share/-M90l_C5MPCYvWv...
# 2   Subclass  https://homebrewery.naturalcrit.com/share/MhTK...
# 3       Race  https://www.gmbinder.com/share/-MVy-6VQ01Ft9Ys...
# 4      Class  https://homebrewery.naturalcrit.com/share/leDB...
# 5   Subclass  https://www.gmbinder.com/share/-MVxOdThHWkEdg0...
# 6   Subclass  https://www.gmbinder.com/share/-MVJujifYnF1PBc...
# 7      Class  https://homebrewery.naturalcrit.com/share/5L4t...
# 9       Race  https://www.gmbinder.com/share/-MVm5LgT_HqPPsP...
#
#                                              src_url  \
# 0  https://www.gmbinder.com/share/-MW5xKc1QPj4TXE...
# 1  https://www.gmbinder.com/share/-MVeY68xfxI2MrE...
# 1  https://www.gmbinder.com/share/-M90l_C5MPCYvWv...
# 2  https://homebrewery.naturalcrit.com/source/MhT...
# 3  https://www.gmbinder.com/share/-MVy-6VQ01Ft9Ys...
# 4  https://homebrewery.naturalcrit.com/source/leD...
# 5  https://www.gmbinder.com/share/-MVxOdThHWkEdg0...
# 6  https://www.gmbinder.com/share/-MVJujifYnF1PBc...
# 7  https://homebrewery.naturalcrit.com/source/5L4...
# 9  https://www.gmbinder.com/share/-MVm5LgT_HqPPsP...
#
#                                                 Text
# 0  \n\n\n\n\n\n## Variant Hobgoblin\n\n\nOften co...
# 1  \n  .phb#p2:after { display:none; }\n  .phb#p5...
# 1  \n    .phb:after {\n        display: none;\n  ...
# 2  ### Fortune Domain\nClerics of the Fortune dom...
# 3  \n/* Background */\n  .phb{ background-image: ...
# 4  \n# Eldritch Brawler\n1\n1 | Eldritch Brawler\...
# 5  ### Oath of Self\n\nAn Oath of Self paladin is...
# 6  Ranger Subclass: Crystalline Trapper\n        ...
# 7  \n  .phb#p1{ text-align:center; }\n  .phb#p1:a...
# 9  # Fairies - A remixed race (v1.1)\n\nFairies h...

# %%
processed_cmts = cwd / 'Data' / 'CommentsProcessed.csv'
processed_posts = cwd / 'Data' / 'PostsProcessed.csv'

posts_df.to_csv(processed_posts,sep=',',encoding='utf-8')
cmts_df.to_csv(processed_cmts,sep=',',encoding='utf-8')

# %%
cmts_df.rename(columns={"post_flair":"flair"},inplace=True)
cmts_df.rename(columns={"post_title":"title"},inplace=True)

# %%
all_data = pd.concat([posts_df[["src_url","sub","flair","title","Text"]], cmts_df[["src_url","sub","flair","title","Text"]]])
all_data.drop_duplicates(subset=["src_url"], inplace=True)

# %%
processed = cwd / 'Data' / 'TrainProcessed.csv'

all_data = all_data[["sub","flair","title","Text","src_url"]]

all_data.to_csv(processed, sep=',', index=False,encoding='utf-8')
